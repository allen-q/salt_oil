# %% [markdown]
# # Changes:
# 1. Based on V37
# 2. Refactored data augmentor. Re-implement the rotate function to preserve positive mask area.
# 3. Changed optimizer to adam

# %% [markdown]
# ## Install required packages if running on google colab

# %%
try:
    import torch
except:
    # !pip install torch torchvision
    # !pip install imageio
    # !pip install Augmentor
    # !git clone https://github.com/allen-q/salt_oil.git
    # !git clone https://github.com/allen-q/salt_net.git

# %%
cd salt_oil
# Out:
# /content/salt_oil

# %%
# !git pull
# Out:
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 13 (delta 8), reused 7 (delta 5), pack-reused 0
# Unpacking objects: 100% (13/13), done.
# From https://github.com/allen-q/salt_oil
#    4b700c3..a0c0158  master     -> origin/master
# Updating 4b700c3..a0c0158
# Fast-forward
#  pytorch_unet/unet/resnet_deep_sup_v11.py         |   22 +-
#  salt_model_v41.2_deep_supervision_90_train.ipynb | 2068 ++++++++++++++++++++++
#  2 files changed, 2077 insertions(+), 13 deletions(-)
#  create mode 100644 salt_model_v41.2_deep_supervision_90_train.ipynb

# %% [markdown]
# ## Import required libs

# %%
import zipfile
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from skimage import io, transform
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as ply
import os
import imageio
from PIL import Image
import glob
import matplotlib.pyplot as plt
import time
import math
import datetime as dt
import pytz
import pickle
from salt_func_lib import *
from torchvision import transforms, utils
from skimage import io, transform
import datetime as dt
import sys
from optparse import OptionParser
import torch.backends.cudnn as cudnn
from torch import optim
from torch.optim import lr_scheduler
import copy
from io import BytesIO
import random
import PIL
import cv2 as cv
% matplotlib inline
% load_ext autoreload
% autoreload 2

# %% [markdown]
# ## Load Unet Modules

# %%
from pytorch_unet.eval import eval_net
from pytorch_unet.unet import UNet
from pytorch_unet.unet.unet_parts import *
from pytorch_unet.unet.resnet_deep_sup_v11 import *
from pytorch_unet.utils import get_ids, split_ids, split_train_val, get_imgs_and_masks, batch

# %%
## Setup data type based on whether GPU is enabled

# %%
if torch.cuda.is_available():
    dtype = torch.cuda.FloatTensor ## UNCOMMENT THIS LINE IF YOU'RE ON A GPU!
else:    
    dtype = torch.FloatTensor
print(f'Data Type set to: {dtype}')
# Out:
# Data Type set to: <class 'torch.cuda.FloatTensor'>

# %%
def setup_train(config_list):
    for conf in config_list:
        log.info(conf)
    for conf in config_list:
        exec(conf)

# %% [markdown]
# ## Create Logger

# %%
run_name = 'salt_model_v41_deep_supervision_run1'
model_file_suffix = f'../salt_net/{run_name}_{get_current_time_as_fname()}.ckp'
#fold = 1

# %%
global log
log = get_logger(run_name)

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Load train and test data from npy files or from raw images if npy files not exist.

# %%
np_train_all, np_train_all_mask, X_test, misc_data = load_all_data()
# Out:
# Try loading data from npy and pickle files...
# Data loaded.

# %%
'''p = Pipeline_Salt()
p.random_brightness(1,0.8,1.2)
p.random_contrast(1,0.8,1.2)
p.rotate_random_align(probability=1)
img = np.c_[np.tile(X_train[840], 2), y_train[840]]
img_in = PIL.Image.fromarray(img)
tsfm = p.torch_transform()
img_out = tsfm(img_in)
plt.imshow(np.array(img_in)[:,:,0], cmap='gray')
plt.imshow(np.array(img_out)[:,:,0], cmap='gray')'''
# Out:
# "p = Pipeline_Salt()\np.random_brightness(1,0.8,1.2)\np.random_contrast(1,0.8,1.2)\np.rotate_random_align(probability=1)\nimg = np.c_[np.tile(X_train[840], 2), y_train[840]]\nimg_in = PIL.Image.fromarray(img)\ntsfm = p.torch_transform()\nimg_out = tsfm(img_in)\nplt.imshow(np.array(img_in)[:,:,0], cmap='gray')\nplt.imshow(np.array(img_out)[:,:,0], cmap='gray')"

# %% [markdown]
# ### Train Val data split

# %%
df_train_mask = pd.DataFrame((np_train_all_mask/255).sum((1,2,3)), columns=['mask_pix'])
df_train_mask.mask_pix = df_train_mask.mask_pix.round(-2)

X_train_ids, X_val_ids = (
    train_test_split(df_train_mask.index.tolist(), 
                     test_size=0.20,
                     stratify = df_train_mask.mask_pix,
                     random_state=0)
)

X_train = np_train_all[X_train_ids]
X_val = np_train_all[X_val_ids]
y_train = np_train_all_mask[X_train_ids]
y_val = np_train_all_mask[X_val_ids]
depth_train = (
    misc_data['df_train_all_depth']
    .reindex(np.array(misc_data['np_train_all_ids'])[X_train_ids])
)
depth_val = (
    misc_data['df_train_all_depth']
    .reindex(np.array(misc_data['np_train_all_ids'])[X_val_ids])
)
depth_test = (
    misc_data['df_train_all_depth']
    .reindex(np.array(misc_data['np_test_ids']))
)
#X_train_mean_img = X_train.mean(0).astype(np.float32)
#X_train_mean_img = X_train.mean((0,1,2)).astype(np.float32)
X_train_mean_img = np.clip(np_train_all/255, 0, 1).mean((0,1,2)).astype(np.float32)
#set mean image to 0 as mean is now being handled within the model.
X_train_mean_img = np.zeros_like(X_train_mean_img)

all_data = {
    'X_train': X_train,
    'X_val': X_val,
    'y_train': y_train,
    'y_val': y_val,
    'X_test': X_test,
    'X_train_mean_img': X_train_mean_img
}

assert X_train_mean_img == np.array([0.])
assert X_train.shape == (3200, 101, 101, 1)
assert y_train.shape == (3200, 101, 101, 1)
assert depth_train.shape == (3200, 1)

# %% [markdown]
# ## Train the model using a small data set to see if it can overfit

# %%
aug_pipeline_config = '''
p = Pipeline_Salt()
p.flip_left_right(probability=0.5)
#p.random_brightness(probability=0.5, min_factor=0.8, max_factor=1.2)
#p.random_contrast(probability=0.5, min_factor=0.8, max_factor=1.2)
#p.rotate_random_align(probability=0.5)
#p.crop_random_align(probability=0.5, min_factor=0.8, max_factor=1.0, mask_diff_pct=0.2)
'''

# %%
data_loader_config = '''
train_data_params = {'batch_size': 8, 'shuffle': True,}
val_data_params = {'batch_size': 8, 'shuffle': True,}
train_dataLoader = (
    DataLoader(SaltDataset(X_train[:16], y_train[:16], depth_train[:16],
                           np.zeros_like(X_train_mean_img), out_size=128,  out_ch=1), **train_data_params)
)

val_dataLoader = (
    DataLoader(SaltDataset(X_val[:8], y_val[:8], depth_val[:8], 
                           np.zeros_like(X_train_mean_img), out_size=128, out_ch=1), **val_data_params)
)

dataloaders = {'train': train_dataLoader, 'val':val_dataLoader}

'''

# %%
model_config = '''
saltnet = UResNet(pretrained=False)

#loss_focal = FocalLoss(0.25, 2, logits=True)
loss_lovasz_hinge = TripleLovaszLoss()
loss_fn_bce = TripleBCELoss(1, 0.05, 0.1)

optimizer = optim.Adam(saltnet.parameters(), lr=1e-4)

scheduler = PolyLR(optimizer, [1e-4], lr_decay_iter=1, max_iter=100, power=0.9)
model_save_name = None
'''

# %%
train_params_config = '''
train_params = {
    'model_save_name': None,
    'save_model_every': 10000,
    'save_log_every': 1000,
    'num_epochs': 100,
    'print_every': 2,
    'log': log,
    'mask_cutoff': 0,
    'model_save_iou_threshold': 0.9
    }
'''

# %%
model_run_config = '''
model = train_model_ds(saltnet, dataloaders, (loss_fn_bce, loss_lovasz_hinge), (1, 0.3), optimizer, scheduler, train_params, all_data)
'''

# %%
config_list = [aug_pipeline_config, data_loader_config, model_config, train_params_config, model_run_config]

# %%
setup_train(config_list)

# %% [markdown]
# ## Train the full with full dataset

# %%
log.info(f'{run_name}, based on salt_model_v37.4_high_lovasz_loss. Implemented deep supervision')
# Out:
# 16/10/2018 13:14:03 - salt_model_v41_deep_supervision_run1 - INFO - salt_model_v41_deep_supervision_run1, based on salt_model_v37.4_high_lovasz_loss. Implemented deep supervision

# %%
aug_pipeline_config = '''
p = Pipeline_Salt()
p.flip_left_right(probability=0.5)
p.rotate90(0.25)
p.rotate270(0.25)
p.random_brightness(probability=0.5, min_factor=0.8, max_factor=1.2)
p.random_contrast(probability=0.5, min_factor=0.8, max_factor=1.2)
p.rotate_random_align(probability=0.5)
p.crop_random_align(probability=0.5, min_factor=0.6, max_factor=1.0, mask_diff_pct=0.2)
'''

# %%
data_loader_config = '''
train_data_params = {'batch_size': 32,
                     #'sampler': weighted_sampler,
                     'shuffle': True,
                     'drop_last': False}

val_data_params = {'batch_size': 32,
                   'shuffle': True,
                   'drop_last': False}

train_dataLoader = (
    DataLoader(SaltDataset(X_train, y_train, depth_train,
                           np.zeros_like(X_train_mean_img), out_size=128,  out_ch=1,
                           transform=p.torch_transform()), **train_data_params)
)

val_dataLoader = (
    DataLoader(SaltDataset(X_val, y_val, depth_val, 
                           np.zeros_like(X_train_mean_img), out_size=128, out_ch=1), **val_data_params)
)

dataloaders = {'train': train_dataLoader, 'val':val_dataLoader}
'''

# %%
model_config = '''
saltnet = UResNet(pretrained=True)
loss_lovasz_hinge = TripleLovaszLoss()
loss_fn_bce = TripleBCELoss(1, 0.05, 0.1)

optimizer = optim.Adam(saltnet.parameters(), lr=1e-3, weight_decay=0.0001)

#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True, threshold=0.0001, min_lr=0.00001)
scheduler = PolyLR(optimizer, [1e-3], lr_decay_iter=1, max_iter=150, power=0.9)
model_save_name = model_file_suffix
log.info(model_save_name)
'''

# %%
train_params_config = '''
train_params = {
    'model_save_name': model_save_name,
    'save_model_every': 20,
    'save_log_every': 2,
    'num_epochs': 150,
    'log': log,
    'mask_cutoff': 0.,
    'model_save_iou_threshold': 0.81
    }
'''

# %%
model_run_config = '''
train_model_ds(saltnet, dataloaders, (loss_fn_bce, loss_lovasz_hinge), (1, 0.3), optimizer, scheduler, train_params, all_data)
'''

# %%
config_list = [aug_pipeline_config, data_loader_config, model_config, train_params_config, model_run_config]

# %%
setup_train(config_list)
# Out:
# 16/10/2018 13:14:15 - salt_model_v41_deep_supervision_run1 - INFO -
# p = Pipeline_Salt()
# p.flip_left_right(probability=0.5)
# p.rotate90(0.25)
# p.rotate270(0.25)
# p.random_brightness(probability=0.5, min_factor=0.8, max_factor=1.2)
# p.random_contrast(probability=0.5, min_factor=0.8, max_factor=1.2)
# p.rotate_random_align(probability=0.5)
# p.crop_random_align(probability=0.5, min_factor=0.6, max_factor=1.0, mask_diff_pct=0.2)
#
# 16/10/2018 13:14:15 - salt_model_v41_deep_supervision_run1 - INFO -
# train_data_params = {'batch_size': 32,
#                      #'sampler': weighted_sampler,
#                      'shuffle': True,
#                      'drop_last': False}
#
# val_data_params = {'batch_size': 32,
#                    'shuffle': True,
#                    'drop_last': False}
#
# train_dataLoader = (
#     DataLoader(SaltDataset(X_train, y_train, depth_train,
#                            np.zeros_like(X_train_mean_img), out_size=128,  out_ch=1,
#                            transform=p.torch_transform()), **train_data_params)
# )
#
# val_dataLoader = (
#     DataLoader(SaltDataset(X_val, y_val, depth_val,
#                            np.zeros_like(X_train_mean_img), out_size=128, out_ch=1), **val_data_params)
# )
#
# dataloaders = {'train': train_dataLoader, 'val':val_dataLoader}
#
# 16/10/2018 13:14:15 - salt_model_v41_deep_supervision_run1 - INFO -
# saltnet = UResNet(pretrained=True)
# loss_lovasz_hinge = TripleLovaszLoss()
# loss_fn_bce = TripleBCELoss(1, 0.05, 0.1)
#
# optimizer = optim.Adam(saltnet.parameters(), lr=1e-3, weight_decay=0.0001)
#
# #scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True, threshold=0.0001, min_lr=0.00001)
# scheduler = PolyLR(optimizer, [1e-3], lr_decay_iter=1, max_iter=150, power=0.9)
# model_save_name = model_file_suffix
# log.info(model_save_name)
#
# 16/10/2018 13:14:15 - salt_model_v41_deep_supervision_run1 - INFO -
# train_params = {
#     'model_save_name': model_save_name,
#     'save_model_every': 20,
#     'save_log_every': 2,
#     'num_epochs': 150,
#     'log': log,
#     'mask_cutoff': 0.,
#     'model_save_iou_threshold': 0.81
#     }
#
# 16/10/2018 13:14:15 - salt_model_v41_deep_supervision_run1 - INFO -
# train_model_ds(saltnet, dataloaders, (loss_fn_bce, loss_lovasz_hinge), (1, 0.3), optimizer, scheduler, train_params, all_data)
# ResNet using pretrained weights.
# 16/10/2018 13:14:16 - salt_model_v41_deep_supervision_run1 - INFO - ../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp
# 16/10/2018 13:14:16 - salt_model_v41_deep_supervision_run1 - INFO - Start Training...
# 16/10/2018 13:14:16 - salt_model_v41_deep_supervision_run1 - INFO - ({'train': <torch.utils.data.dataloader.DataLoader object at 0x7febcb359518>, 'val': <torch.utils.data.dataloader.DataLoader object at 0x7febcb359908>}, (TripleBCELoss(), TripleLovaszLoss()), (1, 0.3), Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0.0001
# ), <salt_func_lib.PolyLR object at 0x7febcad086d8>, {'model_save_name': '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp', 'save_model_every': 20, 'save_log_every': 2, 'num_epochs': 150, 'log': <Logger salt_model_v41_deep_supervision_run1 (DEBUG)>, 'mask_cutoff': 0.0, 'model_save_iou_threshold': 0.81})
# 16/10/2018 13:14:19 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 1/150
# 16/10/2018 13:14:19 - salt_model_v41_deep_supervision_run1 - INFO - --------------------
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# 16/10/2018 13:18:21 - salt_model_v41_deep_supervision_run1 - INFO - Train IOU: 0.4667, Acc: 0.7795, Loss: [0.591, 0.319, 0.9099] at epoch 1
# 16/10/2018 13:18:41 - salt_model_v41_deep_supervision_run1 - INFO - ['../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-1-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-2-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-3-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-4-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-5-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-6-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-7-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-8-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-9-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-10-Of-10']
# 16/10/2018 13:18:41 - salt_model_v41_deep_supervision_run1 - INFO - Best Val Mean IOU so far: 0.379375
# 16/10/2018 13:18:41 - salt_model_v41_deep_supervision_run1 - INFO - Val   IOU: 0.3794, Acc: 0.7527, Best Val IOU: 0.3794 at epoch 1
# 16/10/2018 13:18:41 - salt_model_v41_deep_supervision_run1 - INFO - LR: [0.000994]
# 16/10/2018 13:18:41 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 2/150
# 16/10/2018 13:18:41 - salt_model_v41_deep_supervision_run1 - INFO - --------------------
# 16/10/2018 13:18:41 - salt_model_v41_deep_supervision_run1 - INFO - Pushing logs to git.
# /content/salt_net
# From https://github.com/allen-q/salt_net
#    9314dfd..aa3bb22  master     -> origin/master
# Already up to date.
# [master ccc820c] Pushing logs to git
#  2 files changed, 80 insertions(+)
#  create mode 100644 logs/SaltNet_2018_10_17_00h.log
#  create mode 100644 logs/salt_model_v41_deep_supervision_run1_2018_10_17_00h.log
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.67 KiB | 1.67 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/allen-q/salt_net.git
#    aa3bb22..ccc820c  master -> master
# 16/10/2018 13:23:02 - salt_model_v41_deep_supervision_run1 - INFO - Train IOU: 0.5038, Acc: 0.8232, Loss: [0.532, 0.303, 0.835] at epoch 2
# 16/10/2018 13:23:22 - salt_model_v41_deep_supervision_run1 - INFO - ['../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-1-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-2-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-3-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-4-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-5-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-6-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-7-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-8-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-9-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_17_00_13_36.ckp-chunk-10-Of-10']
# 16/10/2018 13:23:22 - salt_model_v41_deep_supervision_run1 - INFO - Best Val Mean IOU so far: 0.45237499999999997
# 16/10/2018 13:23:22 - salt_model_v41_deep_supervision_run1 - INFO - Val   IOU: 0.4524, Acc: 0.8208, Best Val IOU: 0.4524 at epoch 2
# 16/10/2018 13:23:22 - salt_model_v41_deep_supervision_run1 - INFO - LR: [0.000988]
# 16/10/2018 13:23:22 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 3/150
# 16/10/2018 13:23:22 - salt_model_v41_deep_supervision_run1 - INFO - --------------------

# %%
setup_train(config_list)
# Out:
# 16/10/2018 12:18:10 - salt_model_v41_deep_supervision_run1 - INFO -
# p = Pipeline_Salt()
# p.flip_left_right(probability=0.5)
# p.rotate90(0.25)
# p.rotate270(0.25)
# p.random_brightness(probability=0.5, min_factor=0.8, max_factor=1.2)
# p.random_contrast(probability=0.5, min_factor=0.8, max_factor=1.2)
# p.rotate_random_align(probability=0.5)
# p.crop_random_align(probability=0.5, min_factor=0.6, max_factor=1.0, mask_diff_pct=0.2)
#
# 16/10/2018 12:18:10 - salt_model_v41_deep_supervision_run1 - INFO -
# train_data_params = {'batch_size': 32,
#                      #'sampler': weighted_sampler,
#                      'shuffle': True,
#                      'drop_last': False}
#
# val_data_params = {'batch_size': 32,
#                    'shuffle': True,
#                    'drop_last': False}
#
# train_dataLoader = (
#     DataLoader(SaltDataset(X_train, y_train, depth_train,
#                            np.zeros_like(X_train_mean_img), out_size=128,  out_ch=1,
#                            transform=p.torch_transform()), **train_data_params)
# )
#
# val_dataLoader = (
#     DataLoader(SaltDataset(X_val, y_val, depth_val,
#                            np.zeros_like(X_train_mean_img), out_size=128, out_ch=1), **val_data_params)
# )
#
# dataloaders = {'train': train_dataLoader, 'val':val_dataLoader}
#
# 16/10/2018 12:18:10 - salt_model_v41_deep_supervision_run1 - INFO -
# saltnet = UResNet(pretrained=True)
# loss_lovasz_hinge = TripleLovaszLoss()
# loss_fn_bce = TripleBCELoss(1, 0.05, 0.1)
#
# optimizer = optim.Adam(saltnet.parameters(), lr=1e-3, weight_decay=0.0001)
#
# #scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True, threshold=0.0001, min_lr=0.00001)
# scheduler = PolyLR(optimizer, [1e-3], lr_decay_iter=1, max_iter=150, power=0.9)
# model_save_name = model_file_suffix
# log.info(model_save_name)
#
# 16/10/2018 12:18:10 - salt_model_v41_deep_supervision_run1 - INFO -
# train_params = {
#     'model_save_name': model_save_name,
#     'save_model_every': 20,
#     'save_log_every': 2,
#     'num_epochs': 150,
#     'log': log,
#     'mask_cutoff': 0.,
#     'model_save_iou_threshold': 0.81
#     }
#
# 16/10/2018 12:18:10 - salt_model_v41_deep_supervision_run1 - INFO -
# train_model_ds(saltnet, dataloaders, (loss_fn_bce, loss_lovasz_hinge), (1, 0.3), optimizer, scheduler, train_params, all_data)
# ResNet using pretrained weights.
# 16/10/2018 12:18:11 - salt_model_v41_deep_supervision_run1 - INFO - ../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp
# 16/10/2018 12:18:11 - salt_model_v41_deep_supervision_run1 - INFO - Start Training...
# 16/10/2018 12:18:11 - salt_model_v41_deep_supervision_run1 - INFO - ({'train': <torch.utils.data.dataloader.DataLoader object at 0x7fcaae4c62b0>, 'val': <torch.utils.data.dataloader.DataLoader object at 0x7fcaae4c6390>}, (TripleBCELoss(), TripleLovaszLoss()), (1, 0.3), Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0.0001
# ), <salt_func_lib.PolyLR object at 0x7fcaad2e1208>, {'model_save_name': '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp', 'save_model_every': 20, 'save_log_every': 2, 'num_epochs': 150, 'log': <Logger salt_model_v41_deep_supervision_run1 (DEBUG)>, 'mask_cutoff': 0.0, 'model_save_iou_threshold': 0.81})
# 16/10/2018 12:18:11 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 1/150
# 16/10/2018 12:18:11 - salt_model_v41_deep_supervision_run1 - INFO - --------------------
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# 16/10/2018 12:21:46 - salt_model_v41_deep_supervision_run1 - INFO - Train IOU: 0.4464, Acc: 0.7792, Loss: [0.5985, 0.3391, 0.9376] at epoch 1
# 16/10/2018 12:22:04 - salt_model_v41_deep_supervision_run1 - INFO - ['../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-1-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-2-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-3-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-4-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-5-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-6-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-7-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-8-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-9-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-10-Of-10']
# 16/10/2018 12:22:04 - salt_model_v41_deep_supervision_run1 - INFO - Best Val Mean IOU so far: 0.544375
# 16/10/2018 12:22:04 - salt_model_v41_deep_supervision_run1 - INFO - Val   IOU: 0.5444, Acc: 0.8813, Best Val IOU: 0.5444 at epoch 1
# 16/10/2018 12:22:04 - salt_model_v41_deep_supervision_run1 - INFO - LR: [0.000994]
# 16/10/2018 12:22:04 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 2/150
# 16/10/2018 12:22:04 - salt_model_v41_deep_supervision_run1 - INFO - --------------------
# 16/10/2018 12:22:04 - salt_model_v41_deep_supervision_run1 - INFO - Pushing logs to git.
# /content/salt_net
# Already up to date.
# [master b7beb0e] Pushing logs to git
#  4 files changed, 1511 insertions(+)
#  create mode 100644 logs/SaltNet_2018_10_16_22h.log
#  create mode 100644 logs/SaltNet_2018_10_16_23h.log
#  create mode 100644 logs/salt_model_v37.4_high_lovasz_loss_2018_10_16_22h.log
#  create mode 100644 logs/salt_model_v41_deep_supervision_run1_2018_10_16_23h.log
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 11.80 KiB | 5.90 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/allen-q/salt_net.git
#    e6cf95d..b7beb0e  master -> master
# 16/10/2018 12:25:55 - salt_model_v41_deep_supervision_run1 - INFO - Train IOU: 0.5210, Acc: 0.8360, Loss: [0.5065, 0.2991, 0.8056] at epoch 2
# 16/10/2018 12:26:11 - salt_model_v41_deep_supervision_run1 - INFO - Val   IOU: 0.5386, Acc: 0.8674, Best Val IOU: 0.5444 at epoch 2
# 16/10/2018 12:26:11 - salt_model_v41_deep_supervision_run1 - INFO - LR: [0.000988]
# 16/10/2018 12:26:11 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 3/150
# 16/10/2018 12:26:11 - salt_model_v41_deep_supervision_run1 - INFO - --------------------
# 16/10/2018 12:29:45 - salt_model_v41_deep_supervision_run1 - INFO - Train IOU: 0.5428, Acc: 0.8437, Loss: [0.494, 0.2916, 0.7856] at epoch 3
# 16/10/2018 12:30:03 - salt_model_v41_deep_supervision_run1 - INFO - ['../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-1-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-2-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-3-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-4-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-5-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-6-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-7-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-8-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-9-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-10-Of-10']
# 16/10/2018 12:30:03 - salt_model_v41_deep_supervision_run1 - INFO - Best Val Mean IOU so far: 0.57975
# 16/10/2018 12:30:03 - salt_model_v41_deep_supervision_run1 - INFO - Val   IOU: 0.5797, Acc: 0.8861, Best Val IOU: 0.5797 at epoch 3
# 16/10/2018 12:30:03 - salt_model_v41_deep_supervision_run1 - INFO - LR: [0.000982]
# 16/10/2018 12:30:03 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 4/150
# 16/10/2018 12:30:03 - salt_model_v41_deep_supervision_run1 - INFO - --------------------
# 16/10/2018 12:30:03 - salt_model_v41_deep_supervision_run1 - INFO - Pushing logs to git.
# /content/salt_net
# From https://github.com/allen-q/salt_net
#    e6cf95d..b7beb0e  master     -> origin/master
# Already up to date.
# [master 3a24905] Pushing logs to git
#  1 file changed, 13 insertions(+)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 627 bytes | 627.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/allen-q/salt_net.git
#    b7beb0e..3a24905  master -> master
# 16/10/2018 12:33:56 - salt_model_v41_deep_supervision_run1 - INFO - Train IOU: 0.5701, Acc: 0.8595, Loss: [0.4573, 0.2757, 0.733] at epoch 4
# 16/10/2018 12:34:15 - salt_model_v41_deep_supervision_run1 - INFO - ['../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-1-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-2-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-3-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-4-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-5-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-6-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-7-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-8-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-9-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-10-Of-10']
# 16/10/2018 12:34:15 - salt_model_v41_deep_supervision_run1 - INFO - Best Val Mean IOU so far: 0.580875
# 16/10/2018 12:34:15 - salt_model_v41_deep_supervision_run1 - INFO - Val   IOU: 0.5809, Acc: 0.8906, Best Val IOU: 0.5809 at epoch 4
# 16/10/2018 12:34:15 - salt_model_v41_deep_supervision_run1 - INFO - LR: [0.000976]
# 16/10/2018 12:34:15 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 5/150
# 16/10/2018 12:34:15 - salt_model_v41_deep_supervision_run1 - INFO - --------------------
# 16/10/2018 12:37:49 - salt_model_v41_deep_supervision_run1 - INFO - Train IOU: 0.5701, Acc: 0.8548, Loss: [0.458, 0.2717, 0.7297] at epoch 5
# 16/10/2018 12:38:04 - salt_model_v41_deep_supervision_run1 - INFO - Val   IOU: 0.5433, Acc: 0.8661, Best Val IOU: 0.5809 at epoch 5
# 16/10/2018 12:38:04 - salt_model_v41_deep_supervision_run1 - INFO - LR: [0.0009699]
# 16/10/2018 12:38:04 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 6/150
# 16/10/2018 12:38:04 - salt_model_v41_deep_supervision_run1 - INFO - --------------------
# 16/10/2018 12:38:04 - salt_model_v41_deep_supervision_run1 - INFO - Pushing logs to git.
# /content/salt_net
# From https://github.com/allen-q/salt_net
#    b7beb0e..3a24905  master     -> origin/master
# Already up to date.
# [master 6740193] Pushing logs to git
#  1 file changed, 13 insertions(+)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 626 bytes | 626.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/allen-q/salt_net.git
#    3a24905..6740193  master -> master
# 16/10/2018 12:41:57 - salt_model_v41_deep_supervision_run1 - INFO - Train IOU: 0.5731, Acc: 0.8567, Loss: [0.4612, 0.2735, 0.7347] at epoch 6
# 16/10/2018 12:42:12 - salt_model_v41_deep_supervision_run1 - INFO - Val   IOU: 0.5779, Acc: 0.8804, Best Val IOU: 0.5809 at epoch 6
# 16/10/2018 12:42:12 - salt_model_v41_deep_supervision_run1 - INFO - LR: [0.0009639]
# 16/10/2018 12:42:12 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 7/150
# 16/10/2018 12:42:12 - salt_model_v41_deep_supervision_run1 - INFO - --------------------
# 16/10/2018 12:45:46 - salt_model_v41_deep_supervision_run1 - INFO - Train IOU: 0.5884, Acc: 0.8671, Loss: [0.4382, 0.2626, 0.7007] at epoch 7
# 16/10/2018 12:46:05 - salt_model_v41_deep_supervision_run1 - INFO - ['../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-1-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-2-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-3-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-4-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-5-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-6-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-7-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-8-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-9-Of-10', '../salt_net/salt_model_v41_deep_supervision_run1_2018_10_16_23_10_20.ckp-chunk-10-Of-10']
# 16/10/2018 12:46:05 - salt_model_v41_deep_supervision_run1 - INFO - Best Val Mean IOU so far: 0.6178750000000001
# 16/10/2018 12:46:05 - salt_model_v41_deep_supervision_run1 - INFO - Val   IOU: 0.6179, Acc: 0.9021, Best Val IOU: 0.6179 at epoch 7
# 16/10/2018 12:46:05 - salt_model_v41_deep_supervision_run1 - INFO - LR: [0.0009579]
# 16/10/2018 12:46:05 - salt_model_v41_deep_supervision_run1 - INFO - Epoch 8/150
# 16/10/2018 12:46:05 - salt_model_v41_deep_supervision_run1 - INFO - --------------------
# 16/10/2018 12:46:05 - salt_model_v41_deep_supervision_run1 - INFO - Pushing logs to git.
# /content/salt_net
# From https://github.com/allen-q/salt_net
#    3a24905..6740193  master     -> origin/master
# Already up to date.
# [master 9614f03] Pushing logs to git
#  1 file changed, 13 insertions(+)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 637 bytes | 637.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# ^C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-f4a88094b801> in <module>()
# ----> 1 setup_train(config_list)
#
# <ipython-input-9-541c93afed69> in setup_train(config_list)
#       3         log.info(conf)
#       4     for conf in config_list:
# ----> 5         exec(conf)
#
# <string> in <module>()
#
# /content/salt_oil/salt_func_lib.py in train_model_ds(model, dataloaders, loss_fns, loss_fn_weights, optimizer, scheduler, train_params, other_data)
#    1277                         loss = losses[-1]
#    1278                         loss.backward()
# -> 1279                         optimizer.step()
#    1280                         iter_count += 1
#    1281             best_iou, best_model = (
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/adam.py in step(self, closure)
#      98                     denom = max_exp_avg_sq.sqrt().add_(group['eps'])
#      99                 else:
# --> 100                     denom = exp_avg_sq.sqrt().add_(group['eps'])
#     101
#     102                 bias_correction1 = 1 - beta1 ** state['step']
#
# KeyboardInterrupt:

# %% [markdown]
# ## Load Trained Model

# %%
loaded_model = saltnet

# %%
loaded_model = UResNet(pretrained=False)

# %%
ls

# %%
cd ../salt_net

# %%
ls

# %%
model_file_suffix = "Unet_res34_bce_lovasz_loss_se_new_aug_finetuen1_2018_09_21_09_41_48.ckp"
model_state_dict = torch.load(join_files(model_file_suffix, '.', returnFileObject=True, removeChunks=False))
loaded_model.load_state_dict(model_state_dict['model'])

# %% [markdown]
# ### Make Predictions on validation set

# %% [markdown]
# ### Set model to evaluation mode

# %%
loaded_model.eval()
assert loaded_model.training == False

# %%
val_dataLoader = DataLoader(SaltDataset(X_val, y_val, depth_val, X_train_mean_img, out_size=128), batch_size=16)

# %%
if torch.cuda.is_available():
    loaded_model.cuda()

# %% [markdown]
# ### Eval model on Val data set

# %%
y_val_pred = []

with torch.no_grad():
    for X_val_batch, y_val_batch, depth_val_batch, X_val_id_batch in val_dataLoader:
        y_val_pred.append(loaded_model(X_val_batch))
y_val_pred = torch.cat(y_val_pred)

# %%
p = Pipeline_Salt()
p.flip_left_right(probability=1)
val_dataLoader = DataLoader(SaltDataset(X_val, y_val, depth_val, X_train_mean_img, out_size=128, out_ch=1,
                           transform=p.torch_transform()), batch_size=16)
y_val_pred_flip = []

with torch.no_grad():
    for X_val_batch, y_val_batch, depth_val_batch, X_val_id_batch in val_dataLoader:
        y_val_pred_flip.append(loaded_model(X_val_batch))
y_val_pred_flip = torch.cat(y_val_pred_flip)
y_val_pred_flip = torch.flip(y_val_pred_flip,[2])

# %% [markdown]
# #### merge normal pred and hflip pred

# %%
y_val_pred_ens = torch.where(y_val_pred.abs() > y_val_pred_flip.abs(), y_val_pred, y_val_pred_flip)

# %% [markdown]
# #### Check normal pred IOU

# %%
y_val_pred_adj = adjust_predictions(0, X_val, y_val_pred.gt(0), y_val.squeeze())

# %% [markdown]
# #### Check TTA pred IOU

# %%
y_val_pred_adj = adjust_predictions(0, X_val, y_val_pred_ens.gt(0), y_val.squeeze())

# %% [markdown]
# ### Find best mask cutoff

# %%
results=[]
for cut_off in np.r_[-0.1:0.1:50j]:
  print(cut_off)
  results.append(calc_mean_iou(adjust_predictions(0, X_val, y_val_pred_ens.gt(cut_off), y_val.squeeze()), y_val.squeeze()))

# %%
MASK_CUTOFF = np.r_[-0.1:0.1:50j][np.argmax(results)]

# %%
print(f'MASK_CUTOFF: {MASK_CUTOFF}')

# %% [markdown]
# #### Find best ZERO_MASK_CUTOFF

# %%
results=[]
for cut_off in range(0, 300, 10):
  print(cut_off)
  results.append(calc_mean_iou(adjust_predictions(cut_off, X_val, y_val_pred_ens.gt(MASK_CUTOFF), y_val.squeeze()), y_val.squeeze()))

# %%
ZERO_MASK_CUTOFF = range(0, 300, 10)[np.argmax(results)]

# %%
print(f'ZERO_MASK_CUTOFF: {ZERO_MASK_CUTOFF}')

# %%
y_val_pred_adj = adjust_predictions(ZERO_MASK_CUTOFF, X_val, y_val_pred_ens.gt(MASK_CUTOFF), y_val.squeeze())

# %% [markdown]
# ### View a few val images with predictions

# %%
for i in range(10):
    rand_id = np.random.choice(X_val_id_batch)
    print(f'Image ID: {rand_id}')
    val_img = X_val[rand_id]/255
    val_mask = y_val[rand_id]
    val_mask_pred = y_val_pred_ens.ge(MASK_CUTOFF)[rand_id]
    plot_img_mask_pred([val_img, val_mask, val_mask_pred], range(3), img_per_line=3)

# %% [markdown]
# ### Eval model on Train data set

# %%
train_dataLoader = DataLoader(SaltDataset(X_train, y_train, depth_train, X_train_mean_img, out_size=128), batch_size=32)
y_train_pred = []

with torch.no_grad():
    for X_train_batch, y_train_batch, depth_train_batch, X_train_id_batch in train_dataLoader:
        y_train_pred.append(loaded_model(X_train_batch))
y_train_pred = torch.cat(y_train_pred)

# %%
p = Pipeline_Salt()
p.flip_left_right(probability=1)
train_dataLoader = DataLoader(SaltDataset(X_train, y_train, depth_train, X_train_mean_img, out_size=128, out_ch=1,
                           transform=p.torch_transform()), batch_size=32)
y_train_pred_flip = []

with torch.no_grad():
    for X_train_batch, y_train_batch, depth_train_batch, X_train_id_batch in train_dataLoader:
        y_train_pred_flip.append(loaded_model(X_train_batch))
y_train_pred_flip = torch.cat(y_train_pred_flip)
y_train_pred_flip = torch.flip(y_train_pred_flip,[2])

# %% [markdown]
# #### merge normal pred and hflip pred

# %%
y_train_pred_ens = torch.where(y_train_pred.abs() > y_train_pred_flip.abs(), y_train_pred, y_train_pred_flip)

# %% [markdown]
# #### Check normal pred IOU

# %%
y_train_pred_adj = adjust_predictions(0, X_train, y_train_pred.gt(0), y_train.squeeze())

# %% [markdown]
# #### Check TTA pred IOU

# %%
y_train_pred_adj = adjust_predictions(0, X_train, y_train_pred_ens.gt(0), y_train.squeeze())

# %% [markdown]
# ### Find best mask cutoff

# %%
results=[]
for cut_off in np.r_[-0.2:0.2:50j]:
  print(cut_off)
  results.append(calc_mean_iou(adjust_predictions(0, X_train, y_train_pred_ens.gt(cut_off), y_train.squeeze()), y_train.squeeze()))

# %%
np.r_[-0.2:0.2:50j][np.argmax(results)]

# %%
MASK_CUTOFF = np.r_[-0.1:0.1:50j][np.argmax(results)]

# %%
MASK_CUTOFF = 0

# %%
print(f'MASK_CUTOFF: {MASK_CUTOFF}')

# %% [markdown]
# #### Find best ZERO_MASK_CUTOFF

# %%
results=[]
for cut_off in range(0, 300, 10):
  print(cut_off)
  results.append(calc_mean_iou(adjust_predictions(cut_off, X_train, y_train_pred_ens.gt(MASK_CUTOFF), y_train.squeeze()), y_train.squeeze()))

# %%
ZERO_MASK_CUTOFF = range(0, 300, 10)[np.argmax(results)]

# %%
print(f'ZERO_MASK_CUTOFF: {ZERO_MASK_CUTOFF}')

# %%
y_val_pred_adj = adjust_predictions(ZERO_MASK_CUTOFF, X_val, y_val_pred_ens.gt(MASK_CUTOFF), y_val.squeeze())

# %%
y_train_pred_adj = adjust_predictions(ZERO_MASK_CUTOFF, X_train, y_train_pred_ens.gt(MASK_CUTOFF), y_train.squeeze())

# %%
for i in range(10):
    rand_id = np.random.choice(X_train_id_batch)
    print(f'Image ID: {rand_id}')
    img = X_train[rand_id]/255
    mask = y_train[rand_id]
    mask_pred = y_train_pred.ge(MASK_CUTOFF)[rand_id]
    plot_img_mask_pred([img, mask, mask_pred], range(3), img_per_line=3)

# %% [markdown]
# ## Make predictions on test set using TTA

# %%
import numpy as np

# %% [markdown]
# ### Predict using original image

# %%
test_dataLoader = DataLoader(SaltDataset(X_test, np.zeros_like(X_test), depth_test, X_train_mean_img, out_size=128), batch_size=32)

# %%
y_test_pred_raw = []
with torch.no_grad():
    for X_test_batch, y_test_batch, depth_test_batch, X_test_id_batch in test_dataLoader:
        y_test_pred_raw.append(loaded_model(X_test_batch))
y_test_pred = torch.cat(y_test_pred_raw)

# %% [markdown]
# ### Predict using flipped images

# %%
p = Pipeline_Salt()
p.flip_left_right(probability=1)
test_dataLoader = DataLoader(SaltDataset(X_test, np.zeros_like(X_test), depth_test, X_train_mean_img, out_size=128, out_ch=1,
                           transform=p.torch_transform()), batch_size=32)
y_test_pred_flip = []

with torch.no_grad():
    for X_test_batch, y_test_batch, depth_test_batch, X_test_id_batch in test_dataLoader:
        y_test_pred_flip.append(loaded_model(X_test_batch))
y_test_pred_flip = torch.cat(y_test_pred_flip)
y_test_pred_flip = torch.flip(y_test_pred_flip,[2])

# %% [markdown]
# ### Combine non-flip and flip predictions

# %%
y_test_pred = torch.where(y_test_pred.abs() > y_test_pred_flip.abs(), y_test_pred, y_test_pred_flip)

# %% [markdown]
# ### Adjust predictions

# %%
MASK_CUTOFF = 0
ZERO_MASK_CUTOFF = 0

# %%
print(f'MASK_CUTOFF:{MASK_CUTOFF}, ZERO_MASK_CUTOFF:{ZERO_MASK_CUTOFF}')

# %%
y_test_pred_adj = adjust_predictions(ZERO_MASK_CUTOFF, X_test, y_test_pred.gt(MASK_CUTOFF))

# %% [markdown]
# ### Show segmentation masks for a few images

# %%
for i in range(10):
    rand_id = np.random.choice(X_test_id_batch)
    print(f'Image ID: {rand_id}')
    img = X_test[rand_id]/255
    mask_pred = y_test_pred.ge(0.5)[rand_id]
    plot_img_mask_pred([img, mask_pred], range(2))

# %% [markdown]
# ### Prepare for submission

# %%
y_test_pred_rle = rle_encoder3d(y_test_pred_adj)

# %%
y_test_pred_adj.shape

# %%
df_test_rle = pd.DataFrame(index=misc_data['np_test_ids'], data=y_test_pred_rle).reset_index()

# %%
df_test_rle.columns = ['id', 'rle_mask']

# %%
df_test_rle[df_test_rle.rle_mask==''].shape

# %%
df_test_rle.shape

# %%
df_test_rle.to_csv(f'submission_{get_current_time_as_fname()}.csv', index=False)

# %%
ls

# %%
from google.colab import files

# %%
files.download('submission_2018_09_21_13_11_16.csv')
